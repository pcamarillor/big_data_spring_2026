# %%
from spark_utils import SparkUtils



"""
Order_ID,
Company,
City,
Customer_Age,
Order_Value,
Delivery_Time_Min,
Distance_Km,
Items_Count,
Product_Category,
Payment_Method,
Customer_Rating,
Discount_Applied,
Delivery_Partner_Rating
"""

columns_types = [
    ("Order_ID","long"),
    ("Company","string"),
    ("City","string"),
    ("Customer_Age","int"),
    ("Order_Value","string"),
    ("Delivery_Time_Min","string"),
    ("Distance_Km","string"),
    ("Items_Count","string")
    ("Product_Category", "string"),
    ("Payment_Method", "string"),
    ("Customer_Rating","float"),
    ("Discount_Applied","float"),
    ("Delivery_Partner_Rating","float")
]

qcommerce_schema = SparkUtils.enerate_schema(columns_types)

qcommerce_df = su.spark \
                .read \
                .option("header","true") \
                .schema(qcommerce_schema) \
                .csv("/opt/spark/work-dir/data/qcommerce/")
qcommerce_df.printSchema()
qcommerce_df.show()
# Out:
# <>:29: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <>:29: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from spark_utils import SparkUtils
#       5 """
#       6 Order_ID,
#       7 Company,
#    (...)
#      18 Delivery_Partner_Rating
#      19 """
#      21 columns_types = [
#      22     ("Order_ID","long"),
#      23     ("Company","string"),
#    (...)
#      34     ("Delivery_Partner_Rating","float")
#      35 ]
#
# ModuleNotFoundError: No module named 'spark_utils'
