# %% [markdown]
# - Create a BankAccount class and add it in your own module (spark/src/Giselle_Module).
# - The class should use a dictionary to store operations (functions) as values and their names as keys.
# - Dynamically select and execute operations based on user input.

# %%
# from Giselle_Module import bank_account
from Giselle_Module.bank_account import BankAccount

# %%
# account = bank_account.BankAccount(1000)
account = BankAccount(1000)

print(account.process("get_balance"))
print(account.process("deposit", 13))
print(account.process("withdraw", 717))
print(account.process("deposit", 14))
print(account.process("get_balance"))
# Out:
# get_balance: 1000
# deposit: 1013
# withdraw: 296
# deposit: 310
# get_balance: 310
