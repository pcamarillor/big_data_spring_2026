# %% [markdown]
# Ejemplo

# %%
import sys, os

sys.path.append(os.path.abspath("../../../"))

from src.BankAccount import BankAccount

account = BankAccount(1000)
print(f"Depósito: {account.process('deposit', 13)}")
print(f"Retiro: {account.process('withdraw', 717)}")
print(f"Saldo actual: {account.process('get_balance')}")
# Out:
# Depósito: 1013
# Retiro: 296
# Saldo actual: 296
