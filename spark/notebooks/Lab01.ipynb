# %% [markdown]
# ### Santiago Villa
# January 28th, 2026
# # Lab 01

# %% [markdown]
# ## Task 2

# %%
collaborations = [
    ["s0001", "s0002", "s0003"],
    ["s0002", "s0003"],
    ["s0001", "s0004"],
    ["s0003", "s0004", "s0005"],
    ["s0001", "s0002"],
    ["s0005"],
]

students = set()

for sub_colab2 in collaborations:
    for e in sub_colab2:
        students.add(e)

print(sorted(students))
# Out:
# ['s0001', 's0002', 's0003', 's0004', 's0005']

# %% [markdown]
# ## Task 3

# %%
students_list = list(students)
pairs = set()
dictionary = {}

for i in range(len(students_list)):
    for j in range(i+1, len(students_list)):
        pairs.add((students_list[i], students_list[j]))

print(pairs)

for pair in pairs:
    a, b = pair
    count = 0

    for sub_colab2 in collaborations:
        if (a in sub_colab2 and b in sub_colab2):
            count
# Out:
# {('s0004', 's0001'), ('s0003', 's0002'), ('s0005', 's0001'), ('s0005', 's0002'), ('s0004', 's0002'), ('s0002', 's0001'), ('s0004', 's0003'), ('s0003', 's0001'), ('s0004', 's0005'), ('s0003', 's0005')}
