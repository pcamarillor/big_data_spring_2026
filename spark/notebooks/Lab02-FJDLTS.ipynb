# %% [markdown]
# # Lab 02: Bank Account Manager
# - Francisco Javier De la Torre Silva 745974
# - 09/02/2026

# %% [markdown]
# ### Import my module

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))
from bank_account_manager import BankAccount

# %% [markdown]
# ### example

# %%
account = BankAccount(1000)
print(f"after op deposit: {account.process('deposit', 13)}")
print(f"after op withdraw: {account.process('withdraw', 717)}")
# Out:
# after op deposit: 1013
# after op withdraw: 296
