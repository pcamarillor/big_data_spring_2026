# %% [markdown]
# # <center> <img src="../img/ITESOLogo.png" alt="ITESO" width="480" height="130"> </center>
# # <center> **Departamento de Electrónica, Sistemas e Informática** </center>
# ---
# ## <center> **Procesamiento de Datos Masivos (Big Data)** </center>
# ---
# ### <center> **Spring 2026** </center>
# ---
# ### <center> **Object Oriented Programming in Python** </center>
# ---
# **Professor**: Pablo Camarillo Ramirez

# %%
from lecture_05_classes import Circle
circle = Circle(0.4)
circle.display()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from lecture_05_classes import Circle
#       2 circle = Circle(0.4)
#       3 circle.display()
#
# ModuleNotFoundError: No module named 'lecture_05_classes'

# %%
from lecture_05_classes import Person

person = Person("Alice", 30)
person.introduce()

# %%
from pcemilio_utils import Student

s = Student("alice",98)

# %%
from lecture_05_classes import Dog

print(Dog.get_species())

# %%
from lecture_05_classes import MathUtils

result = MathUtils.add(7, 13)
print(result)

# %%
from lecture_05_classes import Book
book = Book("A Game of Thrones", "George RR Martin")
print(str(book))
print(repr(book))
book

# %%
from lecture_05_classes import Circle

circle = Circle(5)
print(circle.radius)

# Use the setter method
circle.radius = 10
print(circle.radius)

circle._radius = 14.9
circle
