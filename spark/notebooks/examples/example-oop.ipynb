# %% [markdown]
# # <center> <img src="../img/ITESOLogo.png" alt="ITESO" width="480" height="130"> </center>
# # <center> **Departamento de Electrónica, Sistemas e Informática** </center>
# ---
# ## <center> **Procesamiento de Datos Masivos (Big Data)** </center>
# ---
# ### <center> **Spring 2026** </center>
# ---
# ### <center> **Object Oriented Programming in Python** </center>
# ---
# **Professor**: Pablo Camarillo Ramirez

# %%
from lecture_05_classes import Circle
circle = Circle(0.4)
circle.display()
# Out:
# Figure: Circle
# Area: 0.5026548245743669
# Perimeter: 2.5132741228718345

# %%
from lecture_05_classes import Person

person = Person("Alice", 30)
person.introduce()
# Out:
# Hi, I'm Alice and I'm 30 years old.

# %%
from lecture_05_classes import Dog

print(Dog.get_species())
# Out:
# Canis familiaris

# %%
from lecture_05_classes import MathUtils

result = MathUtils.add(7, 13)
print(result)
# Out:
# 20

# %%
from lecture_05_classes import Book
book = Book("A Game of Thrones", "George RR Martin")
print(str(book))
print(repr(book))
book
# Out:
# A Game of Thrones by George RR Martin
# Book('A Game of Thrones', 'George RR Martin')
# Book('A Game of Thrones', 'George RR Martin')

# %%
from lecture_05_classes import Circle

circle = Circle(5)
print(circle.radius)

# Use the setter method
circle.radius = 10
print(circle.radius)

circle._radius = 14.9
circle
# Out:
# 5
# 10
# Circle(Radius:'14.9')

# %%
from nico_utils import Student

student = Student("Nico", "Sistemas")
student.information()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from nico_utils import Student
#       3 student = Student("Nico", "Sistemas")
#       4 student.information()
#
# ImportError: cannot import name 'Student' from 'nico_utils' (/opt/spark/work-dir/src/nico_utils.py)
