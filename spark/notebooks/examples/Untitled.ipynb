# %%
import findspark
findspark.init()

# %%
from  pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
        .appName("Hello world spark") \
        .master("spark://spark-master:7077") \
        .config("spark.ui.port", "4040") \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/10 01:06:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
data = [4243, 54, 32, 54]

rdd = spark.sparkContext.parallelize(data)
rdd
# Out:
# ParallelCollectionRDD[0] at readRDDFromFile at PythonRDD.scala:297

# %%
sq = rdd.map(lambda x: x**2)
sq
# Out:
# PythonRDD[1] at RDD at PythonRDD.scala:56

# %%
result = sq.collect()
result.__class__
# Out:
# list

# %%
spark.sparkContext.stop()
