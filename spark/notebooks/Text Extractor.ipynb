# %%
from text_extractor  import extract_text
import pytesseract

spark = SparkSession.builder \
    .appName("TextExtractorMapReduce") \
    .getOrCreate()

sc = spark.sparkContext
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from text_extractor  import extract_text
#       2 import pytesseract
# ----> 4 spark = SparkSession.builder \
#       5     .appName("TextExtractorMapReduce") \
#       6     .getOrCreate()
#       8 sc = spark.sparkContext
#
# NameError: name 'SparkSession' is not defined

# %%
image_paths = [
    "/cambia/esta/ruta/imagen1.jpg",
    "/cambia/esta/ruta/imagen2.jpg"
]

rdd_images = sc.parallelize(image_paths)
