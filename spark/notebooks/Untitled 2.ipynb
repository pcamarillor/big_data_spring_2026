# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Neo4jSpark") \
    .config("spark.jars.packages",
            "org.neo4j:neo4j-connector-apache-spark_2.13:5.3.10_for_spark_3") \
    .config("spark.neo4j.url", "bolt://neo4j-iteso:7687") \
    .config("spark.neo4j.authentication.type", "basic") \
    .config("spark.neo4j.authentication.basic.username", "neo4j") \
    .config("spark.neo4j.authentication.basic.password", "neo4j123") \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("Neo4jSpark") \
#       5     .config("spark.jars.packages",
#    (...)
#      10     .config("spark.neo4j.authentication.basic.password", "neo4j123") \
#      11     .getOrCreate()
#
# ModuleNotFoundError: No module named 'pyspark'
