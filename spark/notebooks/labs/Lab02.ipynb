# %% [markdown]
# ## The Notebook should import the BankAccount class from your module.

# %%
# Lab 02

from src.AlexTModule.BankAccount import BankAccount

# %%
# Uso

account = BankAccount(100)
account.balance()
account.deposit(50)
account.balance()
account.withdraw(20)
account.balance()
# Out:
# Balance: 100
# Deposited 50
# Balance: 150
# Withdrew 20
# Balance: 130
