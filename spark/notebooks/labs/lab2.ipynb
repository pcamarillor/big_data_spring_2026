# %%
from BankAccount import BanckAccount

b=BanckAccount(1000)
b.process('deposit',10)

b.process('get_balance')

b.process('withdraw',500)

b.process('get_balance')
# Out:
# Actual amount=1010
# Actual amount=510
