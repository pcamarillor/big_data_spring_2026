# %%
from bankAccount import *

# %%
process = BankAccount.process

# %%
account1 = BankAccount(1000)
account2 = BankAccount(0)

# %%
process["deposit"](account1, 200)
process["get_balance"](account1)
# Out:
# 1200

# %%
process["get_balance"](account2)
# Out:
# 0

# %%
process["withdraw"](account2,200)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 process["withdraw"](account2,200)
#
# File /opt/spark/work-dir/src/bankAccount.py:13, in BankAccount.withdraw(self, amount)
#      11 def withdraw(self, amount):
#      12     if amount > self.balance:
# ---> 13         raise Exception("Insufficient funds")
#      14     self.balance -= amount
#
# Exception: Insufficient funds

# %%
process["transfer"]( 500, account1, account2)
process["get_balance"](account1)
process["get_balance"](account2)
# Out:
# Transferred 500 to target account. New balance: 700
# 500

# %%
process["transfer"]( 700, account2, account1)
process["get_balance"](account1)
process["get_balance"](account2)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 process["transfer"]( 700, account2, account1)
#       2 process["get_balance"](account1)
#       3 process["get_balance"](account2)
#
# File /opt/spark/work-dir/src/bankAccount.py:21, in BankAccount.transfer(amount, account, target_account)
#      20 def transfer( amount, account,target_account):
# ---> 21     account.withdraw(amount)
#      22     target_account.deposit(amount)
#      23     print(f"Transferred {amount} to target account. New balance: {account.get_balance()}")
#
# File /opt/spark/work-dir/src/bankAccount.py:13, in BankAccount.withdraw(self, amount)
#      11 def withdraw(self, amount):
#      12     if amount > self.balance:
# ---> 13         raise Exception("Insufficient funds")
#      14     self.balance -= amount
#
# Exception: Insufficient funds
