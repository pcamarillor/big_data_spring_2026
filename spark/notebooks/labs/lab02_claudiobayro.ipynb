# %% [markdown]
# # Lab 02: Bank Account Manager
# Claudio Xavier Bayro Jablonski 731886
# This notebook demonstrates the implementation of the BankAccount class using OOP and dynamic function execution with a dictionary.

# %%
import sys
import os

sys.path.append(os.path.abspath("../../src"))

from cbayro.BankAccount import BankAccount

# %%
account = BankAccount(1000)
account.get_balance()
# Out:
# 1000

# %%
account.process("deposit", 13)
# Out:
# 1013

# %%
account.process("withdraw", 717)
# Out:
# 296

# %%
account.process("get_balance")
# Out:
# 296
