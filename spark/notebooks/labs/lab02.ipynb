# %%
from bank_account import *

# %%
account = BankAccount(1000)
print("Cuenta creada con éxito.")
# Out:
# Cuenta creada con éxito.

# %%
print(account.process("deposit", 13))
print(account.process("withdraw", 717))
print(account.process("get_balance"))
# Out:
# Depósito: $13. Nuevo Saldo: $1013
# Retiro: $717. Nuevo Saldo: $296
# Saldo actual: $296

# %%
print(account.process("withdraw", 5000))

print(account.process("transferir", 500))
# Out:
# Error: Fondos insuficientes. Saldo actual: $296
# Error: La operación 'transferir' no es válida.
