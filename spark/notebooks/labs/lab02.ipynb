# %%
from lab02_code import BanckAccunt
account = BanckAccunt(1000)
account.process("deposit", 13)
account.process("deposit", 130)
account.process("get_balance")
account.process("withdraw", 1500)
account.process("withdraw", 150)
account.process("withdraw", 712)
account.process("get_balance")
# Out:
# El balance es de 1143
# Erro: No hay suficiente dinero en la cuenta. No puedes retirar $1500 dólares
# El balance es de 281
