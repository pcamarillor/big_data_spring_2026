# %% [markdown]
# <div style="text-align: center;">
#     <hr>
#     <h1>LAB 02</h1>
#     <h3>PROCESAMIENTO DE DATOS MASIVOS</h3>
#     <br>
#     <p style="text-align: center;"><strong>Estudiante:</strong> Saul Razo Magallanes - 739974</p>
#     <p style="text-align: center;">Ingeniería en Sistemas Computacionales</p>
#     <p style="text-align: center;"><strong>Profesor:</strong> Pablo Camarillo Ramírez</p>
#     <p style="text-align: center;"><strong>Fecha:</strong> 08/02/2026</p>
#     <hr>
# </div>

# %%
from lab2.BankAccount import BankAccount

# %% [markdown]
# <h3>Casos válidos</h3>
# <hr>

# %%
account = BankAccount(1123)
print(account)
# Out:
# El balance es de $1123.00

# %%
account.process("deposit", 2000)
print(account)
# Out:
# El balance es de $3123.00

# %%
account.process("withdraw", 498)
print(account)
# Out:
# El balance es de $2625.00

# %%
account.process("get_balance")
# Out:
# 2625

# %% [markdown]
# <h3>Excepciones</h3>
# <hr>

# %%
account.process("withdraw", 5000)
print(account)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 account.process("withdraw", 5000)
#       2 print(account)
#
# File /opt/spark/work-dir/src/lab2/BankAccount.py:34, in BankAccount.process(self, operation, amount)
#      32     return operations[operation]()
#      33 else:
# ---> 34     return operations[operation](amount)
#
# File /opt/spark/work-dir/src/lab2/BankAccount.py:17, in BankAccount.withdraw(self, amount)
#      15     raise ValueError("El monto a retirar debe ser positivo")
#      16 if amount > self.balance:
# ---> 17     raise ValueError(f"Fondos insuficientes. Saldo actual: {self.balance}")
#      18 self.balance -= amount
#      19 return self.balance
#
# ValueError: Fondos insuficientes. Saldo actual: 2625

# %%
account.process("deposit", -50)
print(account)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 account.process("deposit", -50)
#       2 print(account)
#
# File /opt/spark/work-dir/src/lab2/BankAccount.py:34, in BankAccount.process(self, operation, amount)
#      32     return operations[operation]()
#      33 else:
# ---> 34     return operations[operation](amount)
#
# File /opt/spark/work-dir/src/lab2/BankAccount.py:9, in BankAccount.deposit(self, amount)
#       7 def deposit(self, amount):
#       8     if amount <= 0:
# ----> 9         raise ValueError("El monto a depositar debe ser positivo")
#      10     self.balance += amount
#      11     return self.balance
#
# ValueError: El monto a depositar debe ser positivo

# %%
account.process("transfer", 100)
print(account)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 account.process("transfer", 100)
#       2 print(account)
#
# File /opt/spark/work-dir/src/lab2/BankAccount.py:29, in BankAccount.process(self, operation, amount)
#      22 operations = {
#      23     'deposit': self.deposit,
#      24     'withdraw': self.withdraw,
#      25     'get_balance': self.get_balance,
#      26 }
#      28 if operation not in operations:
# ---> 29     raise ValueError(f"Operación '{operation}' no válida")
#      31 if operation == 'get_balance':
#      32     return operations[operation]()
#
# ValueError: Operación 'transfer' no válida
