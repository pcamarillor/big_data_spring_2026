# %%
from utils import BankAccount

cuenta = BankAccount(1000)

print(cuenta.process("depositar", 13))
print(cuenta.process("retirar", 717))
print(cuenta.process("consultar_saldo"))
# Out:
# Se depositaron 13. Saldo actual: 1013
# Se retiraron 717. Saldo actual: 296
# Saldo actual: 296
