# %% [markdown]
# Luis Guillermo Rivera Stephens
# Student ID: 746651
#
# # Lab 2: Bank Account

# %%
from BankAccount_LGRS import BankAccount

# %%
account = BankAccount(100)
account.process(action = "deposit", amount = 50)
result = account.process(action = "get_balance", amount = 0)
print(result)
account.process(action = "withdraw", amount = 20)
result = account.process(action = "get_balance", amount = 0)
print(result)
account.process(action = "transfer", amount = 10)
result = account.process(action = "get_balance", amount = 0)
print(result)

try:
    account.process("invalid_action", 10)
except ValueError as e:
    print(e)
# Out:
# 150
# 130
# 120
# Invalid action: None

# %% [markdown]
# ## /src/BankAccount_LGRS.py
#
# class BankAccount:
#     def __init__(self, balance):
#         self.balance = balance
#
#     def process(self, action, amount = 0):
#         if action == "get_balance":
#             return self._get_balance()
#
#         actions = {
#             "deposit": self._deposit,
#             "withdraw": self._withdraw,
#             "transfer": self._transfer,
#         }
#         action = actions.get(action, None)
#         if action is None:
#             raise ValueError(f"Invalid action: {action}")
#
#         return action(amount)
#
#     def _deposit(self, amount):
#         self.balance += amount
#
#     def _withdraw(self, amount):
#         self.balance -= amount
#
#     def _get_balance(self):
#         return self.balance
#
#     def _transfer(self, amount):
#         self.balance -= amount
#         return amount
