# %% [markdown]
# # Lab 02: Bank Account Manager
# ### Santiago Villa
# #### Date: February 4th, 2026

# %%
from lab02_module import BankAccount

account = BankAccount(1000)
account.process("deposit", 45)
account.process("withdraw", 500)
# Out:
# Deposit Successful.
#    New Balance: 1045
# Withdrawal Successful.
#    New Balance: 545
