# %%
from nico_utils import BankAccount

#Open a new balance 0 account
account = BankAccount()

#Operations
account.process("get_balance")
account.process("deposit", 1000)
account.process("withdraw", 1)
print("------------------")

#Incorrect operations
account.process("send", 2000)
account.process("withdraw", 9999)

print("------------------")
account2 = BankAccount(-666) #Warning for negative
account2.process("deposit", -1) #warning
account2.process("withdraw", 1) #warning
account2.process("deposit", 888) #correct
account2.process("withdraw", 889) #warning
# Out:
# Current balance: 0
# 1000 deposited. New balance: 1000
# 1 withdrawn. New balance: 999
# ------------------
# WARNING: Invalid operation
# WARNING: Insufficient funds
# ------------------
# WARNING: Initial balance cannot be negative. New balance = 0.
# WARNING: Deposit amount cannot be negative
# WARNING: Insufficient funds
# 888 deposited. New balance: 888
# WARNING: Insufficient funds
# False
