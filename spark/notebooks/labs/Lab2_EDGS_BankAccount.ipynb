# %% [markdown]
# ### <center> *Lab 02: Bank Account Manager* </center>
# ---
# **Student**: Emilio Daniel Guzmán Seda

# %%
from lab2_utils import BankAccount

account = BankAccount(1000)

account.process("deposit", 13)

account.process("withdraw", 717)

account.process("get_balance", 0)
# Out:
# The balance is: 296
