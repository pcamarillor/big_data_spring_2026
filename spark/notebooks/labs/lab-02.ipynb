# %% [markdown]
# # Lab 02: Bank Account Manager

# %%
from src.BankAccount import BankAccount

# %% [markdown]
# ### Example Usage

# %%
account = BankAccount(1000)

account
# Out:
# BankAccount(balance=1000)

# %%
account.process("deposit", 500)

account
# Out:
# BankAccount(balance=1500)

# %%
account.process("withdraw", 200)

account
# Out:
# BankAccount(balance=1300)

# %%
account.process("get_balance")
# Out:
# 1300
