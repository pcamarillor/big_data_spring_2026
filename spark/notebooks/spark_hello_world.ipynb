# %%
import findspark #it's going to look for an existing installation that we've already have

findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
#.master represents the url, to find the master node

spark = SparkSession.builder \
        .appName("1st SparkSession") \
        .master("spark://spark-master:7077") \
        .config("spark.ui.port","4040") \
        .getOrCreate()

#create SparkContext
sc =
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/10 00:56:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
data = [4243, 54, 32, 54]

rdd = spark.sparkContext.parallelize(data) #receive a python collection and returns a distributed collection

# %%
sq = rdd.map(lambda x: x **2) #rdds are inmutable
sq.__class__
# Out:
# pyspark.core.rdd.PipelinedRDD

# %%
result = sq.collect() # it's the opposite of sparkContext
result.__class__

result
# Out:
# [18003049, 2916, 1024, 2916]

# %%
spark.sparkContext.stop()
