# %% [raw]
# Name: Luis Roberto Navarro Quinn
# Lab 01

# %%
print("Hello")
# Out:
# Hello

# %%
# !pwd
# Out:
# /opt/spark/work-dir/notebooks

# %%
collaborations = [
    ["s0001", "s0002", "s0003"],
    ["s0002", "s0003"],
    ["s0001", "s0004"],
    ["s0003", "s0004", "s0005"],
    ["s0001", "s0002"],
    ["s0005"],
]
